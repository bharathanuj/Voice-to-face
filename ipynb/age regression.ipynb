# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/V2F/driveage_gender_Race.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  Age  Gender  Race  \
# 0           0   24       1     2
# 1           1    3       1     3
# 2           2   35       0     0
# 3           3    5       0     0
# 4           4   23       1     4
#
#                                                  URL
# 0  /content/drive/MyDrive/UTF/crop_part1/24_1_2_2...
# 1  /content/drive/MyDrive/UTF/crop_part1/3_1_3_20...
# 2  /content/drive/MyDrive/UTF/crop_part1/35_0_0_2...
# 3  /content/drive/MyDrive/UTF/crop_part1/5_0_0_20...
# 4  /content/drive/MyDrive/UTF/crop_part1/23_1_4_2...

# %%
import cv2

# %%
path = df["URL"][1]

# %%
path
# Out:
# '/content/drive/MyDrive/UTF/crop_part1/3_1_3_20161219230106056.jpg.chip.jpg'

# %%
img = cv2.imread(path)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
img.shape

# %%
x = []
y = df['Age']
c = 0

# %%
y.head()
# Out:
# 0    24
# 1     3
# 2    35
# 3     5
# 4    23
# Name: Age, dtype: int64

# %%
for i in list(df['URL']):
  img = cv2.imread(i)
  c = c + 1
  x.append(img)
  print(c)
print(x)
# Out:
# Streaming output truncated to the last 5000 lines.
# 4781
# 4782
# 4783
# 4784
# 4785
# 4786
# 4787
# 4788
# 4789
# 4790
# 4791
# 4792
# 4793
# 4794
# 4795
# 4796
# 4797
# 4798
# 4799
# 4800
# 4801
# 4802
# 4803
# 4804
# 4805
# 4806
# 4807
# 4808
# 4809
# 4810
# 4811
# 4812
# 4813
# 4814
# 4815
# 4816
# 4817
# 4818
# 4819
# 4820
# 4821
# 4822
# 4823
# 4824
# 4825
# 4826
# 4827
# 4828
# 4829
# 4830
# 4831
# 4832
# 4833
# 4834
# 4835
# 4836
# 4837
# 4838
# 4839
# 4840
# 4841
# 4842
# 4843
# 4844
# 4845
# 4846
# 4847
# 4848
# 4849
# 4850
# 4851
# 4852
# 4853
# 4854
# 4855
# 4856
# 4857
# 4858
# 4859
# 4860
# 4861
# 4862
# 4863
# 4864
# 4865
# 4866
# 4867
# 4868
# 4869
# 4870
# 4871
# 4872
# 4873
# 4874
# 4875
# 4876
# 4877
# 4878
# 4879
# 4880
# 4881
# 4882
# 4883
# 4884
# 4885
# 4886
# 4887
# 4888
# 4889
# 4890
# 4891
# 4892
# 4893
# 4894
# 4895
# 4896
# 4897
# 4898
# 4899
# 4900
# 4901
# 4902
# 4903
# 4904
# 4905
# 4906
# 4907
# 4908
# 4909
# 4910
# 4911
# 4912
# 4913
# 4914
# 4915
# ...

# %%
f = pd.read_excel("calues1.xlsx")

# %%
len(y)
# Out:
# 9780

# %%
len(x)
# Out:
# 9780

# %%
x[0]
# Out:
# array([[[ 52,  47,  68],
#         [ 58,  53,  74],
#         [ 58,  54,  73],
#         ...,
#         [152, 151, 147],
#         [151, 150, 146],
#         [150, 149, 145]],
#
#        [[ 55,  50,  71],
#         [ 59,  54,  75],
#         [ 59,  55,  74],
#         ...,
#         [152, 151, 147],
#         [151, 150, 146],
#         [151, 150, 146]],
#
#        [[ 59,  55,  74],
#         [ 61,  57,  76],
#         [ 58,  54,  73],
#         ...,
#         [154, 153, 149],
#         [153, 152, 148],
#         [152, 151, 147]],
#
#        ...,
#
#        [[168, 172, 173],
#         [169, 173, 174],
#         [174, 178, 179],
#         ...,
#         [204, 205, 196],
#         [206, 207, 198],
#         [208, 209, 200]],
#
#        [[180, 185, 184],
#         [177, 182, 181],
#         [180, 184, 185],
#         ...,
#         [205, 206, 197],
#         [208, 209, 200],
#         [210, 211, 202]],
#
#        [[183, 188, 187],
#         [182, 187, 186],
#         [188, 192, 193],
# ...

# %%
data1 = pd.DataFrame()

# %%
data1["x"] = x

# %%
data1["y"] = y

# %%
data1.head()
# Out:
#                                                    x   y
# 0  [[[52, 47, 68], [58, 53, 74], [58, 54, 73], [5...  24
# 1  [[[63, 66, 80], [62, 65, 79], [63, 66, 80], [6...   3
# 2  [[[3, 0, 7], [0, 0, 7], [0, 0, 8], [209, 221, ...  35
# 3  [[[15, 2, 94], [15, 3, 93], [17, 3, 91], [16, ...   5
# 4  [[[27, 56, 65], [17, 46, 55], [29, 59, 70], [4...  23

# %%
data1.to_csv("values1.csv", sep='\t')

# %%
data1.to_excel("calues1.xlsx")

# %%
import numpy as np

# %%
x = np.array(x)
y = np.array(y)

# %%
x.shape
# Out:
# (9780, 200, 200, 3)

# %%
x
# Out:
# array([[ 52,  47,  68, ..., 211, 212, 203],
#        [ 63,  66,  80, ...,  78,  40,  90],
#        [  3,   0,   7, ..., 104, 138, 204],
#        ...,
#        [ 92, 101, 105, ..., 247, 242, 239],
#        [177, 188, 215, ..., 112,  84, 160],
#        [ 89,  90, 100, ..., 125, 146, 177]], dtype=uint8)

# %%
for i in range(len(y)):
  if y[i]!=0 and y[i]!= 1:
    y[i] = 1

# %%
x = x/255
# Out:
# array([[[[0.20392157, 0.18431373, 0.26666667],
#          [0.22745098, 0.20784314, 0.29019608],
#          [0.22745098, 0.21176471, 0.28627451],
#          ...,
#          [0.59607843, 0.59215686, 0.57647059],
#          [0.59215686, 0.58823529, 0.57254902],
#          [0.58823529, 0.58431373, 0.56862745]],
#
#         [[0.21568627, 0.19607843, 0.27843137],
#          [0.23137255, 0.21176471, 0.29411765],
#          [0.23137255, 0.21568627, 0.29019608],
#          ...,
#          [0.59607843, 0.59215686, 0.57647059],
#          [0.59215686, 0.58823529, 0.57254902],
#          [0.59215686, 0.58823529, 0.57254902]],
#
#         [[0.23137255, 0.21568627, 0.29019608],
#          [0.23921569, 0.22352941, 0.29803922],
#          [0.22745098, 0.21176471, 0.28627451],
#          ...,
#          [0.60392157, 0.6       , 0.58431373],
#          [0.6       , 0.59607843, 0.58039216],
#          [0.59607843, 0.59215686, 0.57647059]],
#
#         ...,
#
# ...

# %%
import tensorflow as tf
model = tf.keras.models.load_model('/content/drive/MyDrive/V2F/age_detection.hdf5')

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 16)   432         ['input_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 128)  147456      ['activation_2[0][0]']
#
# ...

# %%
a.shape
# Out:
# (64, 64, 3)

# %%
plt.imshow(a)

# %%
age_pred = model.predict(np.expand_dims(a,axis = 0))

# %%
np.expand_dims(a,axis = 0).shape
# Out:
# (1, 64, 64, 3)

# %%
len(age_pred[1][0])
# Out:
# 101

# %%
np.argmax(age_pred[1],axis = 1)[0]
# Out:
# 26

# %%
temp = []
for i in range(len(x)):
  a = cv2.resize(x[i],(64,64))
  a = cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
  age_pred = model.predict(np.expand_dims(a,axis = 0))
  temp.append(np.argmax(age_pred[1],axis = 1)[0])
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 4780
# 4781
# 4782
# 4783
# 4784
# 4785
# 4786
# 4787
# 4788
# 4789
# 4790
# 4791
# 4792
# 4793
# 4794
# 4795
# 4796
# 4797
# 4798
# 4799
# 4800
# 4801
# 4802
# 4803
# 4804
# 4805
# 4806
# 4807
# 4808
# 4809
# 4810
# 4811
# 4812
# 4813
# 4814
# 4815
# 4816
# 4817
# 4818
# 4819
# 4820
# 4821
# 4822
# 4823
# 4824
# 4825
# 4826
# 4827
# 4828
# 4829
# 4830
# 4831
# 4832
# 4833
# 4834
# 4835
# 4836
# 4837
# 4838
# 4839
# 4840
# 4841
# 4842
# 4843
# 4844
# 4845
# 4846
# 4847
# 4848
# 4849
# 4850
# 4851
# 4852
# 4853
# 4854
# 4855
# 4856
# 4857
# 4858
# 4859
# 4860
# 4861
# 4862
# 4863
# 4864
# 4865
# 4866
# 4867
# 4868
# 4869
# 4870
# 4871
# 4872
# 4873
# 4874
# 4875
# 4876
# 4877
# 4878
# 4879
# 4880
# 4881
# 4882
# 4883
# 4884
# 4885
# 4886
# 4887
# 4888
# 4889
# 4890
# 4891
# 4892
# 4893
# 4894
# 4895
# 4896
# 4897
# 4898
# 4899
# 4900
# 4901
# 4902
# 4903
# 4904
# 4905
# 4906
# 4907
# 4908
# 4909
# 4910
# 4911
# 4912
# 4913
# 4914
# ...

# %%
d1 = pd.DataFrame()

# %%
d1['URL']=df['URL']

# %%
d1['Age'] = pd.Series(temp)

# %%
d1.head()
# Out:
#                                                  URL  Age
# 0  /content/drive/MyDrive/UTF/crop_part1/24_1_2_2...   26
# 1  /content/drive/MyDrive/UTF/crop_part1/3_1_3_20...   35
# 2  /content/drive/MyDrive/UTF/crop_part1/35_0_0_2...   31
# 3  /content/drive/MyDrive/UTF/crop_part1/5_0_0_20...   32
# 4  /content/drive/MyDrive/UTF/crop_part1/23_1_4_2...   31

# %%
d1.to_csv('/content/drive/MyDrive/V2F/Age_pred.csv')

# %%
df1 = pd.read_csv('/content/drive/MyDrive/V2F/Age_pred.csv')

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
path = '/content/MicrosoftTeams-image.png'
k = cv2.imread(path)
a = cv2.resize(k,(64,64))
a = cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(a)
age_pred = model.predict(np.expand_dims(a,axis = 0))
np.argmax(age_pred[1],axis = 1)[0]
# Out:
# 28
